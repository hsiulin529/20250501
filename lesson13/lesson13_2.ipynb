# %%
import matplotlib.pyplot as plt
figure,axes=plt.subplots()
x=[0,1,2]
y=[3,4,5]
axes.plot(x,y,marker="o",label='line',linestyle='-.',color='r',markersize=5,linewidth=2)
axes.set_title("line plot on existing axes")
axes.legend()
plt.show()

# %%
# !pip install wget
# Out:
# Requirement already satisfied: wget in c:\users\student\miniconda3\envs\python2_4\lib\site-packages (3.2)

# %%
#下載中文字型
import wget
wget.download("https://github.com/roberthsu2003/machine_learning/raw/refs/heads/main/source_data/ChineseFont.ttf")
# Out:
# 'ChineseFont (2).ttf'

# %%
import matplotlib.pyplot as plt
from matplotlib.font_manager import fontManager
import matplotlib as mpl

fontManager.addfont("ChineseFont.ttf")
mpl.rc('font',family='ChineseFont')

figure, axes = plt.subplots()
x = [0, 1, 2]
y = [3, 4, 5]
axes.plot(x, y, marker='o',label='學生1',linestyle='-.',color='r',markersize=10,linewidth=2)
axes.set_title("折線圖")
axes.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib.font_manager import fontManager
import matplotlib as mpl

fontManager.addfont("ChineseFont.ttf")
mpl.rc('font',family='ChineseFont')

figure, axes = plt.subplots()
x = [1, 2, 3]
y = [3, 4, 5]
axes.plot(x, y, marker='o',label='學生1',linestyle='-.',color='r',markersize=10,linewidth=2)
axes.set_title("折線圖")
axes.set_xticks([1, 2, 3],['第1','第2','第3'])
axes.set_yticks([3, 4, 5],['3', '4', '5'])
axes.legend()
plt.show()
